# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.8.0-py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 11.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /Users/caro/anaconda3/envs/pyviz/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.19.2)
# Requirement already satisfied: scikit-learn>=0.24 in /Users/caro/anaconda3/envs/pyviz/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in /Users/caro/anaconda3/envs/pyviz/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /Users/caro/anaconda3/envs/pyviz/lib/python3.7/site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/caro/anaconda3/envs/pyviz/lib/python3.7/site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.8.0 imblearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Ensemble Learning
#
# ## Initial Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
# Load the data
file_path = Path('Resources/LoanStats_2019Q1.csv')
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %%
#Get unique month values
df["issue_d"].unique()
df["next_pymnt_d"].unique()

months_num = {
    "Jan-2019": 1,
    "Feb-2019": 2,
    "Mar-2019": 3,
    "Apr-2019": 4,
    "May-2019": 5
}

#Get the proper month numbers
df["issue_m_num"] = df["issue_d"].apply(lambda x: months_num[x])
df["next_pymnt_m_num"] = df["next_pymnt_d"].apply(lambda x: months_num[x])

#Pick columns that can be dropped.
df["pymnt_plan"].unique() ##To be dropped
df["hardship_flag"].unique() ##To be dropped
df["debt_settlement_flag"].unique() ##To be dropped

df["initial_list_status"].unique() #1 of 2 can be dropped after encoding
df["application_type"].unique() #1 of 2 can be dropped after encoding


#Dummy encode
loans_binary_encoded = pd.get_dummies(df, columns=["home_ownership", 
                                                   "verification_status", 
                                                   "initial_list_status",
                                                   "application_type"])


clean_df = loans_binary_encoded.drop(["issue_d",
                                                "next_pymnt_d",
                                                "pymnt_plan",
                                                "hardship_flag",
                                                "debt_settlement_flag",
                                                "initial_list_status_f", 
                                                "application_type_Individual"], axis=1)


clean_df.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc loan_status    dti  \
# 0    10500.0    0.1719       375.35     66000.0    low_risk  27.24
# 1    25000.0    0.2000       929.09    105000.0    low_risk  20.23
# 2    20000.0    0.2000       529.88     56000.0    low_risk  24.26
# 3    10000.0    0.1640       353.55     92000.0    low_risk  31.44
# 4    22000.0    0.1474       520.39     52000.0    low_risk  18.76
#
#    delinq_2yrs  inq_last_6mths  open_acc  pub_rec  ...  next_pymnt_m_num  \
# 0          0.0             0.0       8.0      0.0  ...                 5
# 1          0.0             0.0      17.0      1.0  ...                 5
# 2          0.0             0.0       8.0      0.0  ...                 5
# 3          0.0             1.0      10.0      1.0  ...                 5
# 4          0.0             1.0      14.0      0.0  ...                 5
#
#    home_ownership_ANY  home_ownership_MORTGAGE  home_ownership_OWN  \
# 0                   0                        0                   0
# 1                   0                        1                   0
# 2                   0                        1                   0
# 3                   0                        0                   0
# 4                   0                        1                   0
#
#    home_ownership_RENT  verification_status_Not Verified  \
# 0                    1                                 0
# 1                    0                                 0
# 2                    0                                 0
# 3                    1                                 0
# 4                    0                                 1
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                    1                             0
# 1                                    0                             1
# 2                                    0                             1
# 3                                    0                             1
# 4                                    0                             0
#
#    initial_list_status_w  application_type_Joint App
# 0                      1                           0
# 1                      1                           0
# 2                      1                           0
# 3                      1                           0
# 4                      1                           0
#
# [5 rows x 88 columns]

# %% [markdown]
# ## Split the Data into Training and Testing

# %%
# Create our features
X = cleaned_encoded_df.drop(columns="loan_status")
# Create our target
y = cleaned_encoded_df["loan_status"]

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  next_pymnt_m_num  home_ownership_ANY  \
# count   68817.000000  ...      68817.000000        68817.000000
# mean    17604.142828  ...          4.616839            0.009285
# std     21835.880400  ...          0.486161            0.095914
# min         0.000000  ...          4.000000            0.000000
# 25%      6293.000000  ...          4.000000            0.000000
# 50%     12068.000000  ...          5.000000            0.000000
# 75%     21735.000000  ...          5.000000            0.000000
# max    587191.000000  ...          5.000000            1.000000
#
#        home_ownership_MORTGAGE  home_ownership_OWN  home_ownership_RENT  \
# count             68817.000000        68817.000000         68817.000000
# mean                  0.526309            0.106747             0.357659
# std                   0.499311            0.308793             0.479314
# min                   0.000000            0.000000             0.000000
# 25%                   0.000000            0.000000             0.000000
# 50%                   1.000000            0.000000             0.000000
# 75%                   1.000000            0.000000             1.000000
# max                   1.000000            1.000000             1.000000
#
#        verification_status_Not Verified  verification_status_Source Verified  \
# count                      68817.000000                         68817.000000
# mean                           0.478007                             0.373992
# std                            0.499520                             0.483865
# min                            0.000000                             0.000000
# 25%                            0.000000                             0.000000
# 50%                            0.000000                             0.000000
# 75%                            1.000000                             1.000000
# max                            1.000000                             1.000000
#
#        verification_status_Verified  initial_list_status_w  \
# count                  68817.000000           68817.000000
# mean                       0.148001               0.876121
# std                        0.355104               0.329446
# min                        0.000000               0.000000
# 25%                        0.000000               1.000000
# 50%                        0.000000               1.000000
# 75%                        0.000000               1.000000
# max                        1.000000               1.000000
#
#        application_type_Joint App
# count                68817.000000
# mean                     0.139660
# std                      0.346637
# min                      0.000000
# 25%                      0.000000
# 50%                      0.000000
# 75%                      0.000000
# max                      1.000000
#
# [8 rows x 87 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
# Split the X and y into X_train, X_test, y_train, y_test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, 
                                                   y, 
                                                   random_state=70)
X_train
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 13559     6525.0    0.2500       259.44     60000.0   8.90          0.0
# 66744    16000.0    0.2437       463.74     59882.0   9.96          0.0
# 14616     5000.0    0.1992       185.62     94500.0  37.02          1.0
# 63093    14000.0    0.1180       463.67     65000.0  14.97          0.0
# 58681    10000.0    0.0819       314.25     85000.0  15.54          0.0
# 66289     5600.0    0.2437       220.80     89300.0  11.71          1.0
# 49665     8000.0    0.1180       264.96     40000.0  19.95          0.0
# 35295     5000.0    0.0756       155.67     70000.0  13.18          1.0
# 39572     5300.0    0.1691       188.73     65000.0  20.97          1.0
# 52827     8050.0    0.2340       313.30    450000.0  17.19          0.0
# 32871    27000.0    0.1797       685.19     45000.0  16.56          0.0
# 9461     20000.0    0.2000       529.88     96000.0  20.30          0.0
# 51466    40000.0    0.1356      1358.58    102000.0  30.44          0.0
# 63499    12500.0    0.0819       392.81     60000.0   9.36          0.0
# 65124     7200.0    0.0756       224.17     24000.0  14.86          0.0
# 25034    10000.0    0.0702       308.87    110000.0  12.81          0.0
# 52575     3000.0    0.0702        92.66     75000.0   7.98          0.0
# 22750    12000.0    0.1992       445.48     80000.0  22.52          0.0
# 65143    21500.0    0.0702       664.06     70000.0  23.37          0.0
# 32968     7000.0    0.0756       217.94     46000.0  30.71          0.0
# 52045    12000.0    0.2235       333.82     40000.0  51.22          1.0
# 9487      7500.0    0.1033       243.17    180000.0   9.66          0.0
# 41376    20000.0    0.1502       476.01    135000.0  13.20          0.0
# 50523    15000.0    0.1447       516.10    138000.0  16.24          1.0
# 64273    20000.0    0.1298       454.86     58000.0  31.45          0.0
# 14531    17000.0    0.1390       394.68     61000.0  20.28          0.0
# 67771    12000.0    0.1356       407.58     40000.0  15.48          0.0
# 39659    24000.0    0.2631       970.95     30000.0  39.32          0.0
# 61821    16000.0    0.1131       350.36     83201.0  26.58          0.0
# 30735    20000.0    0.1131       657.72    102000.0   5.72          0.0
# ...          ...       ...          ...         ...    ...          ...
# 32968             0.0      13.0      1.0    14945.0  ...                 5
# 52045             1.0      11.0      0.0     5563.0  ...                 5
# 9487              0.0       9.0      0.0     6683.0  ...                 5
# 41376             1.0      12.0      0.0    20212.0  ...                 4
# 50523             0.0      13.0      0.0    21110.0  ...                 4
# 64273             0.0      17.0      0.0    16950.0  ...                 4
# 14531             0.0      13.0      0.0    12047.0  ...                 4
# 67771             0.0       3.0      0.0     5292.0  ...                 5
# 39659             0.0       6.0      0.0     4777.0  ...                 5
# 61821             0.0      16.0      0.0    27842.0  ...                 5
# 30735             0.0       4.0      0.0      122.0  ...                 4
# ...               ...       ...      ...        ...  ...               ...
# 26276             0.0       7.0      0.0     2675.0  ...                 5
# 56277             1.0      28.0      0.0    51870.0  ...                 5
# 46984             1.0      17.0      0.0    23790.0  ...                 4
# 37766             2.0       9.0      0.0     2612.0  ...                 4
# 45649             0.0       9.0      0.0     9784.0  ...                 4
# 62093             0.0       5.0      0.0     5821.0  ...                 5
# 7251              2.0      18.0      0.0     2784.0  ...                 5
# 21364             0.0      11.0      0.0    16115.0  ...                 4
# 61353             0.0      13.0      0.0    23422.0  ...                 5
# 29392             1.0      12.0      0.0    15265.0  ...                 5
# 34                0.0      14.0      0.0     5829.0  ...                 5
# 34135             1.0      20.0      0.0    27938.0  ...                 5
# 26702             2.0      29.0      0.0    42185.0  ...                 5
# 2781              1.0       6.0      0.0     6805.0  ...                 5
# 651               1.0       7.0      0.0     3550.0  ...                 5
# 14186             1.0       8.0      0.0     5495.0  ...                 5
# 62986             2.0       7.0      0.0    21077.0  ...                 5
# 46607             3.0      17.0      1.0    17669.0  ...                 4
# 3682              0.0      20.0      0.0    39086.0  ...                 5
# 1685              0.0       8.0      0.0    30236.0  ...                 5
# 14938             0.0       8.0      0.0    18517.0  ...                 4
# 57641             0.0      16.0      0.0    20994.0  ...                 5
# 19196             0.0       6.0      1.0     2841.0  ...                 4
# 45024             1.0       7.0      0.0    11653.0  ...                 5
# 67272             0.0       8.0      0.0     9672.0  ...                 5
# 27988             0.0      18.0      0.0    12966.0  ...                 5
# 47733             0.0      19.0      0.0    20198.0  ...                 4
# 45492             0.0       7.0      1.0     3141.0  ...                 5
# 21563             1.0      21.0      0.0    25954.0  ...                 4
# 25916             0.0       6.0      0.0     7094.0  ...                 5
#
#        home_ownership_ANY  home_ownership_MORTGAGE  home_ownership_OWN  \
# 13559                   0                        0                   0
# 66744                   0                        1                   0
# 14616                   0                        0                   1
# 63093                   0                        0                   0
# 58681                   0                        1                   0
# 66289                   0                        1                   0
# 49665                   0                        0                   0
# 35295                   0                        1                   0
# 39572                   0                        0                   0
# 52827                   0                        1                   0
# 32871                   0                        0                   0
# 9461                    0                        1                   0
# 51466                   0                        1                   0
# 63499                   0                        0                   0
# 65124                   0                        0                   1
# 25034                   0                        1                   0
# 52575                   0                        1                   0
# 22750                   0                        0                   0
# 65143                   0                        1                   0
# 32968                   0                        1                   0
# 52045                   0                        1                   0
# 9487                    0                        0                   0
# 41376                   0                        0                   0
# 50523                   0                        1                   0
# 52045                                    1                             0
# 9487                                     1                             0
# 41376                                    0                             0
# 50523                                    0                             0
# 64273                                    1                             0
# 14531                                    1                             0
# 67771                                    0                             0
# 39659                                    0                             1
# 61821                                    1                             0
# 30735                                    1                             0
# ...                                    ...                           ...
# 26276                                    0                             0
# 56277                                    1                             0
# 46984                                    0                             0
# 37766                                    1                             0
# 45649                                    0                             0
# 62093                                    1                             0
# 7251                                     0                             0
# 21364                                    1                             0
# 61353                                    1                             0
# 29392                                    1                             0
# 34                                       0                             1
# 34135                                    1                             0
# 26702                                    1                             0
# 2781                                     1                             0
# 651                                      0                             0
# 14186                                    1                             0
# 62986                                    0                             0
# 46607                                    0                             0
# 3682                                     0                             1
# 1685                                     0                             0
# 14938                                    0                             1
# 57641                                    1                             0
# 19196                                    0                             0
# 45024                                    1                             0
# 67272                                    0                             0
# 27988                                    0                             0
# 47733                                    0                             0
# 45492                                    0                             0
# 21563                                    1                             0
# 25916                                    1                             0
#
#        initial_list_status_w  application_type_Joint App
# 13559                      1                           0
# 66744                      1                           0
# 14616                      0                           0
# 63093                      1                           0
# 58681                      1                           0
# 66289                      1                           1
# 49665                      1                           0
# 35295                      1                           0
# 39572                      1                           0
# 52827                      1                           0
# 32871                      1                           0
# 9461                       1                           0
# 51466                      1                           0
# 63499                      1                           0
# 65124                      1                           0
# 25034                      0                           0
# 52575                      1                           0
# 22750                      1                           0
# 65143                      1                           0
# 32968                      1                           0
# 52045                      1                           1
# 9487                       1                           0
# 41376                      1                           0
# 50523                      1                           0
# 64273                      1                           0
# 14531                      1                           0
# 67771                      1                           0
# 39659                      1                           1
# 61821                      1                           0
# 30735                      1                           0
# ...                      ...                         ...
# 26276                      1                           0
# 56277                      1                           0
# 46984                      1                           0
# 37766                      0                           0
# 45649                      0                           0
# 62093                      1                           0
# 7251                       1                           0
# 21364                      1                           0
# 61353                      1                           0
# 29392                      1                           0
# 34                         1                           0
# 34135                      1                           0
# 26702                      1                           0
# 2781                       1                           0
# 651                        1                           0
# 14186                      1                           0
# 62986                      1                           0
# 46607                      0                           0
# 3682                       1                           0
# 1685                       1                           0
# 14938                      1                           0
# 57641                      1                           0
# 19196                      1                           0
# 45024                      1                           0
# 67272                      1                           0
# 27988                      1                           1
# 47733                      1                           0
# 45492                      1                           0
# 21563                      1                           0
# 25916                      1                           0
#
# [51612 rows x 87 columns]

# %% [markdown]
# ## Data Pre-Processing
#
# Scale the training and testing data using the `StandardScaler` from `sklearn`. Remember that when scaling the data, you only scale the features data (`X_train` and `X_testing`).

# %%
# Create the StandardScaler instance
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# When fitting scaling functions, only train on the training dataset
X_scaler = scaler.fit(X_train)
X_scaler
# Out:
# StandardScaler()

# %%
# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Display the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier only, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=1000, random_state=1)
brf.fit(X_train_scaled, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=1000, random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7478795620437956

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   46,    34],
#        [ 1357, 15768]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.03      0.57      0.92      0.06      0.73      0.51        80
#    low_risk       1.00      0.92      0.57      0.96      0.73      0.55     17125
#
# avg / total       0.99      0.92      0.58      0.95      0.73      0.55     17205

# %%
# List the features sorted in descending order by feature importance
importances = brf.feature_importances_ 
sorted(zip(brf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.0778393080607839, 'total_rec_prncp'),
#  (0.06679440460545966, 'total_pymnt'),
#  (0.06438469305413277, 'last_pymnt_amnt'),
#  (0.0629446812711958, 'total_rec_int'),
#  (0.05819745016811501, 'total_pymnt_inv'),
#  (0.03266724484960699, 'int_rate'),
#  (0.031006002666091294, 'issue_m_num'),
#  (0.017921460012528232, 'max_bal_bc'),
#  (0.01669139213983442, 'dti'),
#  (0.016391956295420066, 'installment'),
#  (0.016237691094134647, 'out_prncp'),
#  (0.016109994055118492, 'mo_sin_old_rev_tl_op'),
#  (0.015663213856700362, 'annual_inc'),
#  (0.015505862162404866, 'mths_since_recent_inq'),
#  (0.015218047278446585, 'tot_hi_cred_lim'),
#  (0.014757738327305066, 'out_prncp_inv'),
#  (0.014592423728850305, 'all_util'),
#  (0.014563172983162068, 'il_util'),
#  (0.014184478805530094, 'total_bc_limit'),
#  (0.01415218213758878, 'mo_sin_old_il_acct'),
#  (0.013858736576959846, 'tot_cur_bal'),
#  (0.013783622529175319, 'avg_cur_bal'),
#  (0.013643640758289178, 'revol_bal'),
#  (0.013451981329695365, 'bc_util'),
#  (0.013339005053987153, 'bc_open_to_buy'),
#  (0.012889043459010197, 'total_bal_ex_mort'),
#  (0.012447486243314683, 'mths_since_rcnt_il'),
#  (0.012443196760519762, 'total_bal_il'),
#  (0.011843136544511966, 'total_il_high_credit_limit'),
#  (0.011591624226420119, 'total_rev_hi_lim'),
#  (0.011312896092638396, 'loan_amnt'),
#  (0.011154248292147706, 'mths_since_recent_bc'),
#  (0.010040156935470999, 'mo_sin_rcnt_rev_tl_op'),
#  (0.009914038898601988, 'total_acc'),
#  (0.009907112692880502, 'num_rev_accts'),
#  (0.009708210894494787, 'num_il_tl'),
#  (0.009565745440378734, 'pct_tl_nvr_dlq'),
#  (0.009453039669138668, 'mo_sin_rcnt_tl'),
#  (0.009244607277496477, 'total_rec_late_fee'),
#  (0.009061630219983127, 'open_acc'),
#  (0.008473334382697062, 'num_op_rev_tl'),
#  (0.008189342859288715, 'num_bc_tl'),
#  (0.008172570931428346, 'num_sats'),
#  (0.007985057144081372, 'inq_last_12m'),
#  (0.007638837710258234, 'num_actv_rev_tl'),
#  (0.0075829674354183805, 'num_rev_tl_bal_gt_0'),
#  (0.007385960291142192, 'acc_open_past_24mths'),
#  (0.007289187197633821, 'num_actv_bc_tl'),
#  (0.007114035783277999, 'num_bc_sats'),
#  (0.007060865010169871, 'total_cu_tl'),
#  (0.0068136323130191, 'percent_bc_gt_75'),
#  (0.006604266896441221, 'num_tl_op_past_12m'),
#  (0.006601777907114798, 'open_il_24m'),
#  (0.006320432675591303, 'open_rv_24m'),
#  (0.006283074307636073, 'inq_fi'),
#  (0.006174488108003009, 'open_act_il'),
#  (0.00613306982758056, 'inq_last_6mths'),
#  (0.0060585627173837964, 'mort_acc'),
#  (0.005025952354121702, 'open_acc_6m'),
#  (0.0046715651916805385, 'next_pymnt_m_num'),
#  (0.004553462372604877, 'tot_coll_amt'),
#  (0.0040871834869018984, 'delinq_2yrs'),
#  (0.0038033786783448886, 'open_il_12m'),
#  (0.0037542408766138213, 'open_rv_12m'),
#  (0.00351386026915886, 'num_accts_ever_120_pd'),
#  (0.0021833826346379895, 'verification_status_Not Verified'),
#  (0.0021771725270829587, 'verification_status_Source Verified'),
#  (0.0019513682714776444, 'verification_status_Verified'),
#  (0.0017796820949734023, 'home_ownership_MORTGAGE'),
#  (0.0016730475971577289, 'home_ownership_RENT'),
#  (0.0015424330431476545, 'home_ownership_OWN'),
#  (0.0015020079749417652, 'application_type_Joint App'),
#  (0.0013385120319295003, 'pub_rec_bankruptcies'),
#  (0.0013304929521223451, 'pub_rec'),
#  (0.0012206018319712857, 'initial_list_status_w'),
#  (0.0007856134379427883, 'num_tl_90g_dpd_24m'),
#  (0.00041386222765992284, 'collections_12_mths_ex_med'),
#  (0.0002571216677581994, 'home_ownership_ANY'),
#  (7.703753208004589e-05, 'chargeoff_within_12_mths'),
#  (0.0, 'tax_liens'),
#  (0.0, 'recoveries'),
#  (0.0, 'policy_code'),
#  (0.0, 'num_tl_30dpd'),
#  (0.0, 'num_tl_120dpd_2m'),
#  (0.0, 'delinq_amnt'),
#  (0.0, 'collection_recovery_fee'),
#  (0.0, 'acc_now_delinq')]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
# Train the Classifier
from imblearn.ensemble import EasyEnsembleClassifier

eec = EasyEnsembleClassifier(n_estimators=10, random_state=1)
eec.fit(X_train_scaled, y_train)
# Out:
# EasyEnsembleClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = eec.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9029872262773723

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[   69,    11],
#        [  968, 16157]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.07      0.86      0.94      0.12      0.90      0.81        80
#    low_risk       1.00      0.94      0.86      0.97      0.90      0.82     17125
#
# avg / total       0.99      0.94      0.86      0.97      0.90      0.82     17205

# %% [markdown]
# ### Final Questions
#
# 1. Which model had the best balanced accuracy score?
#
# Easy Ensemble Classifier
#
# 2. Which model had the best recall score?
#
# Easy Ensemble Classifier
#
# 3. Which model had the best geometric mean score?
#
# Easy Ensemble Classifier
#
# 4. What are the top three features?
#
# (0.0778393080607839, 'total_rec_prncp'),
#  (0.06679440460545966, 'total_pymnt'),
#  (0.06438469305413277, 'last_pymnt_amnt'),
